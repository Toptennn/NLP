# %% [markdown]
# # Neural Language Modeling

# %% [markdown]
# In this Exercise, we will be using Pytorch Lightning to implement our neural LM. Your job will be just to write the forward method of the model.

# %% [markdown]
# ## setup

# %%
# #download corpus
# !wget --no-check-certificate https://github.com/ekapolc/nlp_2019/raw/master/HW4/BEST2010.zip
# !unzip BEST2010.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install lightning
# Out:
# Requirement already satisfied: lightning in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (2.5.0.post0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (0.12.0)
# Requirement already satisfied: packaging<25.0,>=20.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (2.6.0+cu126)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (1.6.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.12)
# Requirement already satisfied: setuptools in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.8.0)
# Requirement already satisfied: filelock in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.13.1)
# Requirement already satisfied: networkx in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from torchmetrics<3.0,>=0.7.0->lightning) (2.1.2)
# Requirement already satisfied: colorama in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.7)

# %% [markdown]
# ## code

# %%
total_word_count = 0
best2010 = []
with open(r'C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\NLP\HW2\BEST2010\BEST2010\news.txt','r',encoding='utf-8') as f:
  for i,line in enumerate(f):
    line=line.strip()[:-1] #remove the trailing |
    total_word_count += len(line.split("|"))
    best2010.append(line)

train = best2010[:int(len(best2010)*0.7)]
test = best2010[int(len(best2010)*0.7):]
#Training data
train_word_count =0
for line in train:
    for word in line.split('|'):
        train_word_count+=1
print ('Total sentences in BEST2010 news training dataset :\t'+ str(len(train)))
print ('Total word counts in BEST2010 news training dataset :\t'+ str(train_word_count))
# Out:
# Total sentences in BEST2010 news training dataset :	21678
# Total word counts in BEST2010 news training dataset :	1042797

# %%
# !pip install tokenizers
# Out:
# Requirement already satisfied: tokenizers in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (0.21.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from tokenizers) (0.29.1)
# Requirement already satisfied: filelock in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (6.0.2)
# Requirement already satisfied: requests in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\windows 11\anaconda3\envs\nlp\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2025.1.31)

# %% [markdown]
# Here we are going to use a library from huggingface called `tokenizers`. This will help us create a vocabulary and handle the encoding and decoding, i.e., convert text to its corresponding ID (which will be learned by the tokenizer).

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.pre_tokenizers import CharDelimiterSplit
from tokenizers.trainers import WordLevelTrainer

#Basically, we just use the new tokenizer as our vocab building tool.
#In practice, you will have to use a compatible tokenizer like newmm to tokenize the corpus first then do this step
tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))
tokenizer.pre_tokenizer = CharDelimiterSplit(delimiter="|") #now the tokenizer will split "|" for us
trainer = WordLevelTrainer(min_frequency=3,  #we can set a frequency threshold for taking a word into our vocab. for this example, words with freq < 3 will be excluded from the vocab.
                           special_tokens=["[UNK]", "<s>", "</s>"]) #these are our special tokens: for unknown, begin-of-sentence, and end-of-sentence, respectively.
tokenizer.train_from_iterator(train, trainer=trainer)

# %%
len(tokenizer.get_vocab()) #same as nltk
# Out:
# 9062

# %%
tokenizer.encode("กฎหมาย|กับ|การ|เบียดบัง|คน|จน|asdf").tokens #tokens we get after tokenizing this sentence. unknown words will be tokenized as [UNK]
# Out:
# ['กฎหมาย', 'กับ', 'การ', 'เบียดบัง', 'คน', 'จน', '[UNK]']

# %%
tokenizer.encode("กฎหมาย|กับ|การ|เบียดบัง|คน|จน|asdf").ids #this is what we will feed to the LM
# Out:
# [242, 28, 5, 8883, 22, 190, 0]

# %%
import itertools
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import lightning as L
from tqdm import tqdm

# %%
L.seed_everything(42, workers=True)
# Out:
# Seed set to 42
# 42

# %%
class TextDataset(Dataset):
  def __init__(self, data, seq_len = 128):
    #  data is currently a list of sentences
    #  [sent1,
    #   sent2,
    #   ...,
    #  ]

    data = [d+'|</s>' for d in data] #append an </s> token to each sentence
    encodings = tokenizer.encode_batch(data) #encode (turn token into token_id) data
    token_ids = [enc.ids for enc in encodings] #get the token ids for each sentence
    flatten_token_ids = list(itertools.chain(*token_ids)) #turn a list of token_ids into one long token_ids
    ## now data looks like this [sent1_ids </s> sent2_ids </s> ...]
    encoded = torch.LongTensor(flatten_token_ids)

    #remove some left over tokens so that we can form batches of seq_len (128 in this case). Optionally, we can use padding tokens instead.
    left_over = len(encoded) % seq_len
    encoded = encoded[:len(encoded)-left_over]
    self.encoded = encoded.view(-1, seq_len) #reshape data so it becomes a 2-D matrix of shape (len(encoded)//128, 128), i.e. each row contains data of len==128
    ## now data looks like this
    ## [ [1,2,3, ... , 128] (this is just an example, not actual input_ids)
    ##   [1,2,3, ... , 128]
    ##   [1,2,3, ... , 128]
    ## ]

  def __getitem__(self, idx):
    return self.encoded[idx]

  def __len__(self):
    return len(self.encoded)

# %%
train_batch_size = 64
test_batch_size = 128
train_dataset = TextDataset(train)
train_loader = DataLoader(train_dataset, batch_size = train_batch_size, shuffle = True) #DataLoader will take care of the random sampling and batching of data

test_dataset = TextDataset(test)
test_loader = DataLoader(test_dataset, batch_size = test_batch_size, shuffle = False)

# %% [markdown]
# ## Model : Implement the forward function here

# %%
class LSTM(L.LightningModule):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers, dropout_rate, learning_rate, criterion):

        super().__init__()

        self.num_layers = num_layers
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim

        self.embedding = nn.Embedding(vocab_size, embedding_dim) #this will turn the token ids into vectors
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers,
                    dropout=dropout_rate, batch_first=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(hidden_dim, vocab_size) #turn the vectors back into token ids
        self.learning_rate = learning_rate
        self.criterion = criterion

    def forward(self, src):
        # src shape: (batch_size, seq_len)
        embedded = self.embedding(src)         # (batch_size, seq_len, embedding_dim)
        outputs, _ = self.lstm(embedded)         # (batch_size, seq_len, hidden_dim)
        outputs = self.dropout(outputs)          # regularization ด้วย dropout
        logits = self.fc(outputs)                # (batch_size, seq_len, vocab_size)
        # ปรับ temperature scaling โดยคูณ logits ด้วย 1.3
        return logits * 1.3

    def training_step(self, batch, batch_idx):

        src = batch[:, :-1]
        target = batch[:, 1:]
        prediction = self(src) # run the sequence through the model (the forward method)
        prediction = prediction.reshape(-1, vocab_size)
        target = target.reshape(-1)
        loss = self.criterion(prediction, target)
        self.log("train_loss", loss)
        return loss

    def test_step(self, batch, batch_idx):

        src = batch[:, :-1]  #[batch_size (64) , seq_len-1 (127)] except last words
        target = batch[:, 1:] #[batch_size (64) , seq_len-1 (127)] except first words
        with torch.no_grad(): #disable gradient calculation for faster inference
          prediction = self(src) #[batch_size (64), seq_len-1 (127) , vocab size (9000)]
        prediction = prediction.reshape(-1, vocab_size) #[batch_size*(seq_len-1) (64*127=8128) , vocab]
        target = target.reshape(-1) #[batch_size (64), seq_len-1 (127)] -> [batch_size*(seq_len-1) (8128)]
        loss = self.criterion(prediction, target)
        self.log("test_loss", loss)
        return loss

    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=self.learning_rate)

# %%
vocab_size = tokenizer.get_vocab_size()
embedding_dim = 200
hidden_dim = 512
num_layers = 3
dropout_rate = 0.2
lr = 1e-3

# %%
criterion = nn.CrossEntropyLoss()
model = LSTM(vocab_size, embedding_dim, hidden_dim, num_layers, dropout_rate, lr, criterion)

# %%
from lightning.pytorch.loggers import CSVLogger
csv_logger = CSVLogger("log")

# %% [markdown]
# ### Training

# %%
trainer = L.Trainer(
    max_epochs=20,
    logger=csv_logger,
    deterministic=True
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_dataloaders=train_loader) # takes about 8 mins
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params | Mode
# -------------------------------------------------------
# 0 | embedding | Embedding        | 1.8 M  | train
# 1 | lstm      | LSTM             | 5.7 M  | train
# 2 | dropout   | Dropout          | 0      | train
# 3 | fc        | Linear           | 4.6 M  | train
# 4 | criterion | CrossEntropyLoss | 0      | train
# -------------------------------------------------------
# 12.1 M    Trainable params
# 0         Non-trainable params
# 12.1 M    Total params
# 48.504    Total estimated model params size (MB)
# 5         Modules in train mode
# 0         Modules in eval mode
# Epoch 19: 100%|██████████| 130/130 [00:12<00:00, 10.07it/s, v_num=4]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|██████████| 130/130 [00:13<00:00,  9.78it/s, v_num=4]

# %% [markdown]
# ### Testing

# %%
test_result = trainer.test(model, dataloaders=test_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 39/39 [00:02<00:00, 19.16it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss            4.093596935272217
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
import numpy as np

# %%
print(f"Perplexity : {np.exp(test_result[0]['test_loss'])}")
# Out:
# Perplexity : 59.9551591472106

# %%
model.eval() #disable dropout
# Out:
# LSTM(
#   (embedding): Embedding(9062, 200)
#   (lstm): LSTM(200, 512, num_layers=3, batch_first=True, dropout=0.2)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=512, out_features=9062, bias=True)
#   (criterion): CrossEntropyLoss()
# )

# %%
unk_token_id = tokenizer.encode("[UNK]").ids
eos_token_id = tokenizer.encode("</s>").ids

# %%
def generate_seq(context, max_new_token = 10):
  encoded = tokenizer.encode(context).ids
  with torch.no_grad():
      for i in range(max_new_token):
          src = torch.LongTensor([encoded]).to(model.device)
          prediction = model(src)
          probs = torch.softmax(prediction[:, -1] / 1, dim=-1)
          prediction = torch.multinomial(probs, num_samples=1).item()

          while prediction == unk_token_id:
              prediction = torch.multinomial(probs, num_samples=1).item()

          if prediction == eos_token_id:
              break

          encoded.append(prediction)

  return tokenizer.decode(encoded)

# %%
context = "<s>|วัน|จันทร์"
generate_seq(context, 50)
# Out:
# 'วัน จันทร์   แต่ ยัง ไม่ สามารถ เลือก เข้า มา ก็ ได้   นอก จาก นี้   อัน จะ เป็น การ สั่งการ ให้ ดี กว่า   ว่า จะ มี การ ฟ้องร้อง ความ ไม่ ประมาท   " ก่อนหน้า นี้ ที่ ผม ทำ หน้าที่ เรา ได้ มี กระแส หรือ มี พ.ต.ท.ทักษิณ เป็น'

# %% [markdown]
# ## Questions: Answer the following in MyCourseville
#
# 1. What is the perplexity of the neural LM you trained?
# 2. Paste your favorite sentence generated with the LM.

# %%
1. 59.9551591472106
2. ว่า จะ มี การ ฟ้องร้อง ความ ไม่ ประมาท
